# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard

# %%
from google.colab import drive  
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/cats_and_dogs_filtered'

# %%
# Training folder path
Train_path='/content/drive/MyDrive/cats_and_dogs_filtered/train' 

# Testing folder path
Test_path='/content/drive/MyDrive/cats_and_dogs_filtered/validation'

# %%
model = tf.keras.Sequential()#Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
    #model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(64, 64, 3))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
    
model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2)) ## 
    
#model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.2))
    
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3)) ##
model.add(Dense(2, activation = 'softmax'))

# %%
# Compiling the CNN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/cats_and_dogs_filtered/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/cats_and_dogs_filtered/validation',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
model.compile(optimizer='adam',loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
history = model.fit(training_set, validation_data = test_set, batch_size = 32, epochs = 25, verbose = 1)
# Out:
# Epoch 1/25
# 63/63 [==============================] - 14s 216ms/step - loss: 0.1977 - accuracy: 0.9215 - val_loss: 0.5892 - val_accuracy: 0.7740
# Epoch 2/25
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1709 - accuracy: 0.9345 - val_loss: 0.7312 - val_accuracy: 0.7550
# Epoch 3/25
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1895 - accuracy: 0.9165 - val_loss: 0.6549 - val_accuracy: 0.7760
# Epoch 4/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1590 - accuracy: 0.9380 - val_loss: 0.6718 - val_accuracy: 0.7870
# Epoch 5/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1641 - accuracy: 0.9375 - val_loss: 0.7627 - val_accuracy: 0.7800
# Epoch 6/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1497 - accuracy: 0.9430 - val_loss: 0.7099 - val_accuracy: 0.7600
# Epoch 7/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1538 - accuracy: 0.9355 - val_loss: 0.6374 - val_accuracy: 0.7770
# Epoch 8/25
# 63/63 [==============================] - 13s 203ms/step - loss: 0.1718 - accuracy: 0.9265 - val_loss: 0.8502 - val_accuracy: 0.7720
# Epoch 9/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1409 - accuracy: 0.9430 - val_loss: 0.8079 - val_accuracy: 0.7830
# Epoch 10/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1299 - accuracy: 0.9495 - val_loss: 0.8329 - val_accuracy: 0.7610
# Epoch 11/25
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1442 - accuracy: 0.9465 - val_loss: 0.6086 - val_accuracy: 0.7980
# Epoch 12/25
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1271 - accuracy: 0.9530 - val_loss: 0.8989 - val_accuracy: 0.7810
# Epoch 13/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1311 - accuracy: 0.9480 - val_loss: 0.7272 - val_accuracy: 0.7670
# Epoch 14/25
# 63/63 [==============================] - 13s 203ms/step - loss: 0.1340 - accuracy: 0.9480 - val_loss: 0.8302 - val_accuracy: 0.7690
# Epoch 15/25
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1271 - accuracy: 0.9490 - val_loss: 0.7764 - val_accuracy: 0.7910
# Epoch 16/25
# 63/63 [==============================] - 14s 221ms/step - loss: 0.0996 - accuracy: 0.9615 - val_loss: 0.7430 - val_accuracy: 0.7750
# Epoch 17/25
# 63/63 [==============================] - 13s 203ms/step - loss: 0.1481 - accuracy: 0.9440 - val_loss: 0.6737 - val_accuracy: 0.7760
# Epoch 18/25
# 63/63 [==============================] - 13s 205ms/step - loss: 0.0987 - accuracy: 0.9620 - val_loss: 0.7900 - val_accuracy: 0.7850
# Epoch 19/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.0917 - accuracy: 0.9585 - val_loss: 1.1575 - val_accuracy: 0.7840
# Epoch 20/25
# 63/63 [==============================] - 13s 203ms/step - loss: 0.0974 - accuracy: 0.9615 - val_loss: 0.9365 - val_accuracy: 0.7510
# Epoch 21/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1290 - accuracy: 0.9560 - val_loss: 0.7171 - val_accuracy: 0.7590
# Epoch 22/25
# 63/63 [==============================] - 13s 204ms/step - loss: 0.0989 - accuracy: 0.9585 - val_loss: 0.7733 - val_accuracy: 0.7740
# Epoch 23/25
# 63/63 [==============================] - 13s 203ms/step - loss: 0.1140 - accuracy: 0.9585 - val_loss: 0.7166 - val_accuracy: 0.7810
# Epoch 24/25
# 63/63 [==============================] - 13s 202ms/step - loss: 0.1284 - accuracy: 0.9550 - val_loss: 0.7609 - val_accuracy: 0.7820
# Epoch 25/25
# 63/63 [==============================] - 13s 209ms/step - loss: 0.0965 - accuracy: 0.9615 - val_loss: 0.8316 - val_accuracy: 0.7960

# %%
import matplotlib.pyplot as plt

# %%
# Plot accuracy and  loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(history.history['accuracy']))

plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.plot(range(len(history.history['accuracy'])), acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from tensorflow.keras.models import load_model
model.save('model_CNN.h5')

# %%
 import numpy as np

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model('model_CNN.h5')

# %%
class_dict = {0: "dog", 1: "cat"}
test_img=image.load_img('/content/drive/MyDrive/cats_and_dogs_filtered/validation/cats/cat.2006.jpg',target_size=(64,64))

plt.imshow(test_img)

plt.grid(False)

test_img1 = np.expand_dims(test_img, axis=0)

pred = model.predict(test_img1)
pred = np.argmax(pred)
pred_class =class_dict[pred]
print(pred_class)
# Out:
# cat
